# %%
import numpy as np
from sklearn.decomposition import PCA
import scipy.io as sio
np.random.seed(7)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Data=sio.loadmat('/content/drive/MyDrive/datasets/PaviaU (1).mat')['paviaU']
Label=sio.loadmat('/content/drive/MyDrive/datasets/PaviaU_gt (12).mat')['paviaU_gt']

Data=np.reshape(Data,(Data.shape[0]*Data.shape[1],Data.shape[2]))

Label=np.reshape(Label,(Label.shape[0]*Label.shape[1]))

Labels,counts=np.unique(Label,return_counts=True)

Data=Data[Label>0,:]
Label=Label[Label>0]

Labels,counts=np.unique(Label,return_counts=True)


Labels,counts=np.unique(Label,return_counts=True)

# %%
from sklearn import preprocessing
scaler = preprocessing.StandardScaler().fit(Data)
Data= scaler.transform(Data)

# %%
from sklearn.model_selection import train_test_split

testRatio=0.20

X_train, X_test, y_train, y_test = train_test_split(Data, Label, test_size=testRatio, random_state=345,
                                                        stratify=Label)

# %%
from sklearn import preprocessing
scaler = preprocessing.StandardScaler().fit(X_train)
X_train= scaler.transform(X_train)
X_test=scaler.transform(X_test)

# %%
import matplotlib.pyplot as plt
pca = PCA(n_components=30)
pca.fit_transform(X_train)
newspace=pca.components_
newspace=newspace.transpose()
X_train=np.matmul(X_train,newspace)
print(pca.n_components_)
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Variance (%)') #for each component
plt.title('paviaU Dataset Explained Variance')
plt.show()
X_test=np.matmul(X_test,newspace)
# Out:
# 30

# %%
from sklearn.svm import SVC
from sklearn import metrics
import numpy as np

classifiers = []
Train_acc = []
Valid_acc = []
accuracy = -1
accuracy_train = -1

# Adjusted range for C and gamma
for C in np.arange(1, 102, 50):  # Increased step size for C
    for gamma in np.arange(0.001, 0.1, 0.02):  # Increased step size for gamma

        clf = SVC(C=C, gamma=gamma)
        print("----------------------------------------------------------------")
        clf.fit(X_train, y_train)
        classifiers.append((C, gamma, clf))
        y_pred = clf.predict(X_train)
        acc_train = metrics.accuracy_score(y_train, y_pred)
        Train_acc.append(acc_train)
        y_pred = clf.predict(X_test)
        acc = metrics.accuracy_score(y_test, y_pred)
        Valid_acc.append(acc)

        if acc_train > accuracy_train:
            accuracy_train = acc_train
            best_c_train = C
            best_g_train = gamma
        print(f"C_train= {C} Best C_train = {best_c_train} gamma_train = {gamma} best_gamma_train = {best_g_train} Accuracy_train = {acc_train} Best Accuracy_train = {accuracy_train}\n")

        if acc > accuracy:
            accuracy = acc
            best_c = C
            best_g = gamma
        print(f"C= {C} Best C = {best_c} gamma = {gamma} best_gamma = {best_g} Accuracy = {acc} Best Accuracy = {accuracy}\n")
# Out:
# ----------------------------------------------------------------
# C_train= 1 Best C_train = 1 gamma_train = 0.001 best_gamma_train = 0.001 Accuracy_train = 0.801052016364699 Best Accuracy_train = 0.801052016364699
#
# C= 1 Best C = 1 gamma = 0.001 best_gamma = 0.001 Accuracy = 0.804932211313698 Best Accuracy = 0.804932211313698
#
# ----------------------------------------------------------------
# C_train= 1 Best C_train = 1 gamma_train = 0.021 best_gamma_train = 0.021 Accuracy_train = 0.9390999415546464 Best Accuracy_train = 0.9390999415546464
#
# C= 1 Best C = 1 gamma = 0.021 best_gamma = 0.021 Accuracy = 0.9399251986909771 Best Accuracy = 0.9399251986909771
#
# ----------------------------------------------------------------
# C_train= 1 Best C_train = 1 gamma_train = 0.041 best_gamma_train = 0.041 Accuracy_train = 0.9474284044418468 Best Accuracy_train = 0.9474284044418468
#
# C= 1 Best C = 1 gamma = 0.041 best_gamma = 0.041 Accuracy = 0.947872837774661 Best Accuracy = 0.947872837774661
#
# ----------------------------------------------------------------
# C_train= 1 Best C_train = 1 gamma_train = 0.061 best_gamma_train = 0.061 Accuracy_train = 0.9509643483343074 Best Accuracy_train = 0.9509643483343074
#
# C= 1 Best C = 1 gamma = 0.061 best_gamma = 0.061 Accuracy = 0.9495091164095372 Best Accuracy = 0.9495091164095372
#
# ----------------------------------------------------------------
# C_train= 1 Best C_train = 1 gamma_train = 0.081 best_gamma_train = 0.081 Accuracy_train = 0.9532437171244886 Best Accuracy_train = 0.9532437171244886
#
# C= 1 Best C = 1 gamma = 0.081 best_gamma = 0.081 Accuracy = 0.9533660589060309 Best Accuracy = 0.9533660589060309
#
# ----------------------------------------------------------------
# C_train= 51 Best C_train = 1 gamma_train = 0.001 best_gamma_train = 0.081 Accuracy_train = 0.9374050263004091 Best Accuracy_train = 0.9532437171244886
#
# C= 51 Best C = 1 gamma = 0.001 best_gamma = 0.081 Accuracy = 0.9384057971014492 Best Accuracy = 0.9533660589060309
#
# ----------------------------------------------------------------
# C_train= 51 Best C_train = 51 gamma_train = 0.021 best_gamma_train = 0.021 Accuracy_train = 0.9656049094097019 Best Accuracy_train = 0.9656049094097019
#
# C= 51 Best C = 51 gamma = 0.021 best_gamma = 0.021 Accuracy = 0.9594436652641422 Best Accuracy = 0.9594436652641422
#
# ----------------------------------------------------------------
# C_train= 51 Best C_train = 51 gamma_train = 0.041 best_gamma_train = 0.041 Accuracy_train = 0.9719754529514903 Best Accuracy_train = 0.9719754529514903
#
# C= 51 Best C = 51 gamma = 0.041 best_gamma = 0.041 Accuracy = 0.9628330995792427 Best Accuracy = 0.9628330995792427
#
# ----------------------------------------------------------------
# C_train= 51 Best C_train = 51 gamma_train = 0.061 best_gamma_train = 0.061 Accuracy_train = 0.976271186440678 Best Accuracy_train = 0.976271186440678
#
# C= 51 Best C = 51 gamma = 0.061 best_gamma = 0.061 Accuracy = 0.9647031323048153 Best Accuracy = 0.9647031323048153
#
# ----------------------------------------------------------------
# C_train= 51 Best C_train = 51 gamma_train = 0.081 best_gamma_train = 0.081 Accuracy_train = 0.9792226767971947 Best Accuracy_train = 0.9792226767971947
#
# C= 51 Best C = 51 gamma = 0.081 best_gamma = 0.061 Accuracy = 0.9630668536699393 Best Accuracy = 0.9647031323048153
#
# ----------------------------------------------------------------
# C_train= 101 Best C_train = 51 gamma_train = 0.001 best_gamma_train = 0.081 Accuracy_train = 0.9428696668614845 Best Accuracy_train = 0.9792226767971947
#
# C= 101 Best C = 51 gamma = 0.001 best_gamma = 0.061 Accuracy = 0.9405095839177186 Best Accuracy = 0.9647031323048153
#
# ----------------------------------------------------------------
# C_train= 101 Best C_train = 51 gamma_train = 0.021 best_gamma_train = 0.081 Accuracy_train = 0.9681472822910578 Best Accuracy_train = 0.9792226767971947
#
# C= 101 Best C = 51 gamma = 0.021 best_gamma = 0.061 Accuracy = 0.9592099111734456 Best Accuracy = 0.9647031323048153
#
# ----------------------------------------------------------------
# C_train= 101 Best C_train = 51 gamma_train = 0.041 best_gamma_train = 0.081 Accuracy_train = 0.975073056691993 Best Accuracy_train = 0.9792226767971947
#
# C= 101 Best C = 51 gamma = 0.041 best_gamma = 0.061 Accuracy = 0.9636512388966807 Best Accuracy = 0.9647031323048153
#
# ----------------------------------------------------------------
# C_train= 101 Best C_train = 101 gamma_train = 0.061 best_gamma_train = 0.061 Accuracy_train = 0.9793687901811806 Best Accuracy_train = 0.9793687901811806
#
# C= 101 Best C = 51 gamma = 0.061 best_gamma = 0.061 Accuracy = 0.9645862552594671 Best Accuracy = 0.9647031323048153
#
# ----------------------------------------------------------------
# C_train= 101 Best C_train = 101 gamma_train = 0.081 best_gamma_train = 0.081 Accuracy_train = 0.9830508474576272 Best Accuracy_train = 0.9830508474576272
#
# C= 101 Best C = 51 gamma = 0.081 best_gamma = 0.061 Accuracy = 0.9637681159420289 Best Accuracy = 0.9647031323048153

# %%
import pandas as pd
clf = SVC(C=51,gamma=0.006,decision_function_shape='ovo')
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
from sklearn import metrics
print("Accuracy :",metrics.accuracy_score(y_pred, y_test)*100)
from sklearn.metrics import cohen_kappa_score
print("Cohen Kappa Score :",cohen_kappa_score(y_pred, y_test)*100)
from sklearn.metrics import confusion_matrix,classification_report
mat = confusion_matrix(y_pred, y_test)
pd.DataFrame(mat)
# print(confusion_matrix(y_test, y_pred ))
print(classification_report(y_test, y_pred ))
# Out:
# Accuracy : 95.10285179990649
# Cohen Kappa Score : 93.48880539138867
#               precision    recall  f1-score   support
#
#            1       0.95      0.95      0.95      1326
#            2       0.97      0.99      0.98      3730
#            3       0.87      0.83      0.85       420
#            4       0.99      0.97      0.98       613
#            5       1.00      1.00      1.00       269
#            6       0.95      0.91      0.93      1006
#            7       0.89      0.84      0.86       266
#            8       0.87      0.90      0.89       737
#            9       0.99      1.00      1.00       189
#
#     accuracy                           0.95      8556
#    macro avg       0.94      0.93      0.94      8556
# weighted avg       0.95      0.95      0.95      8556

# %%
print(pd.DataFrame(mat))
# Out:
#       0     1    2    3    4    5    6    7    8
# 0  1257     0    5    0    0    0   43   23    0
# 1     0  3680    1   20    0   87    0    4    0
# 2     8     0  347    0    0    0    0   44    0
# 3     1     6    0  592    0    0    0    0    0
# 4     0     0    0    0  269    0    0    0    0
# 5     2    43    0    1    0  914    0    0    0
# 6    28     0    0    0    0    0  223    0    0
# 7    29     1   67    0    0    5    0  666    0
# 8     1     0    0    0    0    0    0    0  189

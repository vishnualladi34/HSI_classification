# %%
import numpy as np
import pandas as pd
import scipy.io

X = scipy.io.loadmat('/content/Indian_pines_corrected.mat')
y = scipy.io.loadmat('/content/Indian_pines_gt.mat')

X=X["indian_pines_corrected"]
X=np.reshape(X,(21025,200))
X=X.astype(int)

y=y["indian_pines_gt"]
y=y.flatten()
y=y.astype(int)

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)
X = sc.transform(X)

X=np.column_stack((X,y))

d=0
for j in range(0,18):
    c=0
    for row in X:
        if row[200]==j:
            c=c+1
    print(d,c)
    d=d+1

Z = np.empty([0, 201])
i=0
j=0
for row in X:
    if row[200] in (2,3,5,6,8,10,11,12,14):
        Z = np.insert(Z, j,X[i], axis=0)  #row wise, axis=0
        j=j+1
    i=i+1
df=pd.DataFrame(Z)
df.to_csv("./processed_data.csv", sep=',',index=False)


Alfalfa_1 = np.empty([0, 201])
i=0
j=0
for row in X:
    if row[200]==1:
        Alfalfa_1 = np.insert(Alfalfa_1, j,X[i], axis=0)  #row wise, axis=0
        j=j+1
    i=i+1
df=pd.DataFrame(Alfalfa_1)
df.to_csv("./data_Alfalfa_1.csv", sep=',',index=False)

Corn_notil_2 = np.empty([0, 201])
i=0
j=0
for row in X:
    if row[200]==2:
        Corn_notil_2 = np.insert(Corn_notil_2, j,X[i], axis=0)  #row wise, axis=0
        j=j+1
    i=i+1
df=pd.DataFrame(Corn_notil_2)
df.to_csv("./data_Corn_notil_2.csv", sep=',',index=False)

Corn_min_3 = np.empty([0, 201])
i=0
j=0
for row in X:
    if row[200]==3:
        Corn_min_3 = np.insert(Corn_min_3, j,X[i], axis=0)  #row wise, axis=0
        j=j+1
    i=i+1
df=pd.DataFrame(Corn_min_3)
df.to_csv("./data_Corn_min_3.csv", sep=',',index=False)

Corn_4 = np.empty([0, 201])
i=0
j=0
for row in X:
    if row[200]==4:
        Corn_4 = np.insert(Corn_4, j,X[i], axis=0)  #row wise, axis=0
        j=j+1
    i=i+1
df=pd.DataFrame(Corn_4)
df.to_csv("./data_Corn_4.csv", sep=',',index=False)

Grass_5 = np.empty([0, 201])
i=0
j=0
for row in X:
    if row[200]==5:
        Grass_5 = np.insert(Grass_5, j,X[i], axis=0)  #row wise, axis=0
        j=j+1
    i=i+1
df=pd.DataFrame(Grass_5)
df.to_csv("./data_Grass_5.csv", sep=',',index=False)

Grass_trees_6 = np.empty([0, 201])
i=0
j=0
for row in X:
    if row[200]==6:
        Grass_trees_6 = np.insert(Grass_trees_6, j,X[i], axis=0)  #row wise, axis=0
        j=j+1
    i=i+1
df=pd.DataFrame(Grass_trees_6)
df.to_csv("./data_Grass_trees_6.csv", sep=',',index=False)

Gress_pesture_Mowed_7 = np.empty([0, 201])
i=0
j=0
for row in X:
    if row[200]==7:
        Gress_pesture_Mowed_7 = np.insert(Gress_pesture_Mowed_7, j,X[i], axis=0)  #row wise, axis=0
        j=j+1
    i=i+1
df=pd.DataFrame(Gress_pesture_Mowed_7)
df.to_csv("./data_Gress_pesture_Mowed_7.csv", sep=',',index=False)

Hey_Windrowed_8 = np.empty([0, 201])
i=0
j=0
for row in X:
    if row[200]==8:
        Hey_Windrowed_8 = np.insert(Hey_Windrowed_8, j,X[i], axis=0)  #row wise, axis=0
        j=j+1
    i=i+1
df=pd.DataFrame(Hey_Windrowed_8)
df.to_csv("./data_Hey_Windrowed_8.csv", sep=',',index=False)

Oats_9 = np.empty([0, 201])
i=0
j=0
for row in X:
    if row[200]==9:
        Oats_9 = np.insert(Oats_9, j,X[i], axis=0)  #row wise, axis=0
        j=j+1
    i=i+1
df=pd.DataFrame(Oats_9)
df.to_csv("./data_Oats_9.csv", sep=',',index=False)

Soybeans_notil_10 = np.empty([0, 201])
i=0
j=0
for row in X:
    if row[200]==10:
        Soybeans_notil_10 = np.insert(Soybeans_notil_10, j,X[i], axis=0)  #row wise, axis=0
        j=j+1
    i=i+1
df=pd.DataFrame(Soybeans_notil_10)
df.to_csv("./data_Soybeans_notil_10.csv", sep=',',index=False)

Soybeans_min_11 = np.empty([0, 201])
i=0
j=0
for row in X:
    if row[200]==11:
        Soybeans_min_11 = np.insert(Soybeans_min_11, j,X[i], axis=0)  #row wise, axis=0
        j=j+1
    i=i+1
df=pd.DataFrame(Soybeans_min_11)
df.to_csv("./data_Soybeans_min_11.csv", sep=',',index=False)

Soybeans_clean_12 = np.empty([0, 201])
i=0
j=0
for row in X:
    if row[200]==12:
        Soybeans_clean_12 = np.insert(Soybeans_clean_12, j,X[i], axis=0)  #row wise, axis=0
        j=j+1
    i=i+1
df=pd.DataFrame(Soybeans_clean_12)
df.to_csv("./data_Soybeans_clean_12.csv", sep=',',index=False)

Wheat_13 = np.empty([0, 201])
i=0
j=0
for row in X:
    if row[200]==13:
        Wheat_13 = np.insert(Wheat_13, j,X[i], axis=0)  #row wise, axis=0
        j=j+1
    i=i+1
df=pd.DataFrame(Wheat_13)
df.to_csv("./data_Wheat_13.csv", sep=',',index=False)

Wood_14 = np.empty([0, 201])
i=0
j=0
for row in X:
    if row[200]==14:
        Wood_14 = np.insert(Wood_14, j,X[i], axis=0)  #row wise, axis=0
        j=j+1
    i=i+1
df=pd.DataFrame(Wood_14)
df.to_csv("./data_Wood_14.csv", sep=',',index=False)

Buildings_15 = np.empty([0, 201])
i=0
j=0
for row in X:
    if row[200]==15:
        Buildings_15 = np.insert(Buildings_15, j,X[i], axis=0)  #row wise, axis=0
        j=j+1
    i=i+1
df=pd.DataFrame(Buildings_15)
df.to_csv("./data_Buildings_15.csv", sep=',',index=False)

Stone_Steel_tower_16 = np.empty([0, 201])
i=0
j=0
for row in X:
    if row[200]==16:
        Stone_Steel_tower_16 = np.insert(Stone_Steel_tower_16, j,X[i], axis=0)  #row wise, axis=0
        j=j+1
    i=i+1
df=pd.DataFrame(Stone_Steel_tower_16)
df.to_csv("./data_Stone_Steel_tower_16.csv", sep=',',index=False)
# Out:
# 0 10776
# 1 46
# 2 1428
# 3 830
# 4 237
# 5 483
# 6 730
# 7 28
# 8 478
# 9 20
# 10 972
# 11 2455
# 12 593
# 13 205
# 14 1265
# 15 386
# 16 93
# 17 0

# %%
import numpy as np
import scipy.io
data = scipy.io.loadmat('/content/data.mat')
label = scipy.io.loadmat('/content/class.mat')

X=data["data"]
y=label["class"]
y=np.ravel(y)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2, random_state = 0)

lda=LDA()
X_train=lda.fit_transform(X_train,y_train)
X_test=lda.transform(X_test)

from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 18, metric = 'minkowski', p = 2)
classifier= KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
           metric_params=None, n_jobs=1, n_neighbors=18, p=2,
           weights='uniform')
classifier.fit(X_train, y_train)

# Predicting the Test set results
y_pred = classifier.predict(X_test)

from sklearn.metrics import accuracy_score
zoba = accuracy_score(y_test, y_pred)
print(zoba)
# Out:
# 0.7536266349583829

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
data = pd.read_csv("/content/processed_data.csv")
X=data.iloc[:,0:200]
Y=data.iloc[:,200:201]

#spliting the dataset into training & testing dataset
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state=0)

#applying LDA
lda=LDA()
X_train=lda.fit_transform(X_train,Y_train)
X_test=lda.transform(X_test)

#fitting Logistic Regression to the Training set
classifier = LogisticRegression(max_iter=2000)  # Increase max_iter from default 1000
classifier.fit(X_train, Y_train)

#predicting the test set results
Y_pred=classifier.predict(X_test)

accuracy = accuracy_score(Y_test, Y_pred)
print("LogisticRegression",accuracy)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression 0.8408229561451002

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
data = pd.read_csv("/content/processed_data.csv")
X=data.iloc[:,0:200]
Y=data.iloc[:,200:201]

#spliting the dataset into training & testing dataset
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state=0)

#applying LDA
lda=LDA()
X_train=lda.fit_transform(X_train,Y_train)
X_test=lda.transform(X_test)

#fitting Logistic Regression to the Training set
classifier = LogisticRegression(max_iter=2000)  # Increase max_iter from default 1000
classifier.fit(X_train, Y_train)

#predicting the test set results
Y_pred=classifier.predict(X_test)

accuracy = accuracy_score(Y_test, Y_pred)
print("LogisticRegression",accuracy)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression 0.8408229561451002

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
data = pd.read_csv("/content/processed_data.csv")
X=data.iloc[:,0:200]
Y=data.iloc[:,200:201]

#spliting the dataset into training & testing dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.2, random_state=0)

#applying LDA
lda=LDA()
X_train=lda.fit_transform(X_train,y_train)
X_test=lda.transform(X_test)

from sklearn.svm import SVC
from sklearn import metrics
# C_2d_range = range(10)/0.1
# gamma_2d_range = [0.01,0.1,0.2,0.3,1]
classifiers = []
# C_range=10
# Gamma_range = 10
Train_acc=[]
Valid_acc=[]
accuracy = -1
accuracy_train = -1
for C in np.arange(1,102,25):
    for gamma in np.arange(0.001,0.1,0.005):

        clf = SVC(C=C, gamma=gamma)
        print("----------------------------------------------------------------")
        clf.fit(X_train, y_train)
        classifiers.append((C, gamma, clf))
        y_pred = clf.predict(X_train)
        acc_train =metrics.accuracy_score(y_train, y_pred)
        Train_acc.append(acc_train)
        y_pred = clf.predict(X_test)
        acc=metrics.accuracy_score(y_test, y_pred)
        Valid_acc.append(acc)
        if (acc_train>accuracy_train):

            accuracy_train=acc_train
            best_c_train = C
            best_g_train=gamma
        print("C_train= ",C," Best C_train = ",best_c_train," gamma_train = ",gamma," best_gamma_train= ",best_g_train," Accuracy_train = ",acc_train," Best Accuracy_train = ",accuracy_train,"\n")

        if (acc>accuracy):
            accuracy=acc
            best_c = C
            best_g=gamma

        print("C= ",C," Best C = ",best_c," gamma = ",gamma," best_gamma= ",best_g," Accuracy = ",acc," Best Accuracy = ",accuracy,"\n")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  1  Best C_train =  1  gamma_train =  0.001  best_gamma_train=  0.001  Accuracy_train =  0.8433734939759037  Best Accuracy_train =  0.8433734939759037
#
# C=  1  Best C =  1  gamma =  0.001  best_gamma=  0.001  Accuracy =  0.8381158635625339  Best Accuracy =  0.8381158635625339
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  1  Best C_train =  1  gamma_train =  0.006  best_gamma_train=  0.006  Accuracy_train =  0.862731826181129  Best Accuracy_train =  0.862731826181129
#
# C=  1  Best C =  1  gamma =  0.006  best_gamma=  0.006  Accuracy =  0.8538170005414185  Best Accuracy =  0.8538170005414185
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  1  Best C_train =  1  gamma_train =  0.011  best_gamma_train=  0.011  Accuracy_train =  0.8697712197103019  Best Accuracy_train =  0.8697712197103019
#
# C=  1  Best C =  1  gamma =  0.011  best_gamma=  0.011  Accuracy =  0.8565240931239848  Best Accuracy =  0.8565240931239848
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  1  Best C_train =  1  gamma_train =  0.016  best_gamma_train=  0.016  Accuracy_train =  0.874373900094761  Best Accuracy_train =  0.874373900094761
#
# C=  1  Best C =  1  gamma =  0.016  best_gamma=  0.016  Accuracy =  0.8592311857065512  Best Accuracy =  0.8592311857065512
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  1  Best C_train =  1  gamma_train =  0.021  best_gamma_train=  0.021  Accuracy_train =  0.8780289698118316  Best Accuracy_train =  0.8780289698118316
#
# C=  1  Best C =  1  gamma =  0.021  best_gamma=  0.021  Accuracy =  0.8613968597726043  Best Accuracy =  0.8613968597726043
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  1  Best C_train =  1  gamma_train =  0.026000000000000002  best_gamma_train=  0.026000000000000002  Accuracy_train =  0.8810071747664816  Best Accuracy_train =  0.8810071747664816
#
# C=  1  Best C =  1  gamma =  0.026000000000000002  best_gamma=  0.026000000000000002  Accuracy =  0.8646453708716838  Best Accuracy =  0.8646453708716838
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  1  Best C_train =  1  gamma_train =  0.031  best_gamma_train=  0.031  Accuracy_train =  0.8837146338161636  Best Accuracy_train =  0.8837146338161636
#
# C=  1  Best C =  1  gamma =  0.031  best_gamma=  0.031  Accuracy =  0.8700595560368165  Best Accuracy =  0.8700595560368165
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  1  Best C_train =  1  gamma_train =  0.036000000000000004  best_gamma_train=  0.036000000000000004  Accuracy_train =  0.8852037362934886  Best Accuracy_train =  0.8852037362934886
#
# C=  1  Best C =  1  gamma =  0.036000000000000004  best_gamma=  0.031  Accuracy =  0.8695181375203032  Best Accuracy =  0.8700595560368165
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  1  Best C_train =  1  gamma_train =  0.041  best_gamma_train=  0.041  Accuracy_train =  0.8864220928658454  Best Accuracy_train =  0.8864220928658454
#
# C=  1  Best C =  1  gamma =  0.041  best_gamma=  0.031  Accuracy =  0.8700595560368165  Best Accuracy =  0.8700595560368165
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  1  Best C_train =  1  gamma_train =  0.046  best_gamma_train=  0.046  Accuracy_train =  0.8896710437254637  Best Accuracy_train =  0.8896710437254637
#
# C=  1  Best C =  1  gamma =  0.046  best_gamma=  0.046  Accuracy =  0.8727666486193828  Best Accuracy =  0.8727666486193828
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  1  Best C_train =  1  gamma_train =  0.051000000000000004  best_gamma_train=  0.051000000000000004  Accuracy_train =  0.8904832814403683  Best Accuracy_train =  0.8904832814403683
#
# C=  1  Best C =  1  gamma =  0.051000000000000004  best_gamma=  0.051000000000000004  Accuracy =  0.8749323226854359  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  1  Best C_train =  1  gamma_train =  0.056  best_gamma_train=  0.056  Accuracy_train =  0.8922431298226614  Best Accuracy_train =  0.8922431298226614
#
# C=  1  Best C =  1  gamma =  0.056  best_gamma=  0.051000000000000004  Accuracy =  0.8743909041689226  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  1  Best C_train =  1  gamma_train =  0.061  best_gamma_train=  0.061  Accuracy_train =  0.8946798429673751  Best Accuracy_train =  0.8946798429673751
#
# C=  1  Best C =  1  gamma =  0.061  best_gamma=  0.051000000000000004  Accuracy =  0.8738494856524093  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  1  Best C_train =  1  gamma_train =  0.066  best_gamma_train=  0.066  Accuracy_train =  0.896033572492216  Best Accuracy_train =  0.896033572492216
#
# C=  1  Best C =  1  gamma =  0.066  best_gamma=  0.051000000000000004  Accuracy =  0.871142393069843  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  1  Best C_train =  1  gamma_train =  0.07100000000000001  best_gamma_train=  0.07100000000000001  Accuracy_train =  0.8971165561120888  Best Accuracy_train =  0.8971165561120888
#
# C=  1  Best C =  1  gamma =  0.07100000000000001  best_gamma=  0.051000000000000004  Accuracy =  0.8722252301028696  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  1  Best C_train =  1  gamma_train =  0.076  best_gamma_train=  0.076  Accuracy_train =  0.8996886422092866  Best Accuracy_train =  0.8996886422092866
#
# C=  1  Best C =  1  gamma =  0.076  best_gamma=  0.051000000000000004  Accuracy =  0.8722252301028696  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  1  Best C_train =  1  gamma_train =  0.081  best_gamma_train=  0.081  Accuracy_train =  0.9005008799241911  Best Accuracy_train =  0.9005008799241911
#
# C=  1  Best C =  1  gamma =  0.081  best_gamma=  0.051000000000000004  Accuracy =  0.873308067135896  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  1  Best C_train =  1  gamma_train =  0.08600000000000001  best_gamma_train=  0.08600000000000001  Accuracy_train =  0.9019899824015162  Best Accuracy_train =  0.9019899824015162
#
# C=  1  Best C =  1  gamma =  0.08600000000000001  best_gamma=  0.051000000000000004  Accuracy =  0.8738494856524093  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  1  Best C_train =  1  gamma_train =  0.091  best_gamma_train=  0.091  Accuracy_train =  0.9026668471639366  Best Accuracy_train =  0.9026668471639366
#
# C=  1  Best C =  1  gamma =  0.091  best_gamma=  0.051000000000000004  Accuracy =  0.8738494856524093  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  1  Best C_train =  1  gamma_train =  0.096  best_gamma_train=  0.091  Accuracy_train =  0.9026668471639366  Best Accuracy_train =  0.9026668471639366
#
# C=  1  Best C =  1  gamma =  0.096  best_gamma=  0.051000000000000004  Accuracy =  0.8727666486193828  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  26  Best C_train =  1  gamma_train =  0.001  best_gamma_train=  0.091  Accuracy_train =  0.8624610802761609  Best Accuracy_train =  0.9026668471639366
#
# C=  26  Best C =  1  gamma =  0.001  best_gamma=  0.051000000000000004  Accuracy =  0.8494856524093124  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  26  Best C_train =  1  gamma_train =  0.006  best_gamma_train=  0.091  Accuracy_train =  0.8853391092459727  Best Accuracy_train =  0.9026668471639366
#
# C=  26  Best C =  1  gamma =  0.006  best_gamma=  0.051000000000000004  Accuracy =  0.8646453708716838  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  26  Best C_train =  1  gamma_train =  0.011  best_gamma_train=  0.091  Accuracy_train =  0.8911601462027887  Best Accuracy_train =  0.9026668471639366
#
# C=  26  Best C =  1  gamma =  0.011  best_gamma=  0.051000000000000004  Accuracy =  0.8678938819707634  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  26  Best C_train =  1  gamma_train =  0.016  best_gamma_train=  0.091  Accuracy_train =  0.8972519290645729  Best Accuracy_train =  0.9026668471639366
#
# C=  26  Best C =  1  gamma =  0.016  best_gamma=  0.051000000000000004  Accuracy =  0.8695181375203032  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  26  Best C_train =  26  gamma_train =  0.021  best_gamma_train=  0.021  Accuracy_train =  0.9029375930689049  Best Accuracy_train =  0.9029375930689049
#
# C=  26  Best C =  1  gamma =  0.021  best_gamma=  0.051000000000000004  Accuracy =  0.8662696264212236  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  26  Best C_train =  26  gamma_train =  0.026000000000000002  best_gamma_train=  0.026000000000000002  Accuracy_train =  0.9065926627859754  Best Accuracy_train =  0.9065926627859754
#
# C=  26  Best C =  1  gamma =  0.026000000000000002  best_gamma=  0.051000000000000004  Accuracy =  0.8700595560368165  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  26  Best C_train =  26  gamma_train =  0.031  best_gamma_train=  0.031  Accuracy_train =  0.9084878841207527  Best Accuracy_train =  0.9084878841207527
#
# C=  26  Best C =  1  gamma =  0.031  best_gamma=  0.051000000000000004  Accuracy =  0.8706009745533297  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  26  Best C_train =  26  gamma_train =  0.036000000000000004  best_gamma_train=  0.036000000000000004  Accuracy_train =  0.913225937457696  Best Accuracy_train =  0.913225937457696
#
# C=  26  Best C =  1  gamma =  0.036000000000000004  best_gamma=  0.051000000000000004  Accuracy =  0.8700595560368165  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  26  Best C_train =  26  gamma_train =  0.041  best_gamma_train=  0.041  Accuracy_train =  0.9171517530797346  Best Accuracy_train =  0.9171517530797346
#
# C=  26  Best C =  1  gamma =  0.041  best_gamma=  0.051000000000000004  Accuracy =  0.8716838115863562  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  26  Best C_train =  26  gamma_train =  0.046  best_gamma_train=  0.046  Accuracy_train =  0.9195884662244483  Best Accuracy_train =  0.9195884662244483
#
# C=  26  Best C =  1  gamma =  0.046  best_gamma=  0.051000000000000004  Accuracy =  0.871142393069843  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  26  Best C_train =  26  gamma_train =  0.051000000000000004  best_gamma_train=  0.051000000000000004  Accuracy_train =  0.9210775687017734  Best Accuracy_train =  0.9210775687017734
#
# C=  26  Best C =  1  gamma =  0.051000000000000004  best_gamma=  0.051000000000000004  Accuracy =  0.8695181375203032  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  26  Best C_train =  26  gamma_train =  0.056  best_gamma_train=  0.056  Accuracy_train =  0.9232435359415189  Best Accuracy_train =  0.9232435359415189
#
# C=  26  Best C =  1  gamma =  0.056  best_gamma=  0.051000000000000004  Accuracy =  0.8684353004872767  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  26  Best C_train =  26  gamma_train =  0.061  best_gamma_train=  0.061  Accuracy_train =  0.9259509949912007  Best Accuracy_train =  0.9259509949912007
#
# C=  26  Best C =  1  gamma =  0.061  best_gamma=  0.051000000000000004  Accuracy =  0.8678938819707634  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  26  Best C_train =  26  gamma_train =  0.066  best_gamma_train=  0.066  Accuracy_train =  0.9279815892784622  Best Accuracy_train =  0.9279815892784622
#
# C=  26  Best C =  1  gamma =  0.066  best_gamma=  0.051000000000000004  Accuracy =  0.8678938819707634  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  26  Best C_train =  26  gamma_train =  0.07100000000000001  best_gamma_train=  0.07100000000000001  Accuracy_train =  0.9308244212806281  Best Accuracy_train =  0.9308244212806281
#
# C=  26  Best C =  1  gamma =  0.07100000000000001  best_gamma=  0.051000000000000004  Accuracy =  0.8678938819707634  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  26  Best C_train =  26  gamma_train =  0.076  best_gamma_train=  0.076  Accuracy_train =  0.9332611344253419  Best Accuracy_train =  0.9332611344253419
#
# C=  26  Best C =  1  gamma =  0.076  best_gamma=  0.051000000000000004  Accuracy =  0.8668110449377369  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  26  Best C_train =  26  gamma_train =  0.081  best_gamma_train=  0.081  Accuracy_train =  0.935020982807635  Best Accuracy_train =  0.935020982807635
#
# C=  26  Best C =  1  gamma =  0.081  best_gamma=  0.051000000000000004  Accuracy =  0.8684353004872767  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  26  Best C_train =  26  gamma_train =  0.08600000000000001  best_gamma_train=  0.08600000000000001  Accuracy_train =  0.93651008528496  Best Accuracy_train =  0.93651008528496
#
# C=  26  Best C =  1  gamma =  0.08600000000000001  best_gamma=  0.051000000000000004  Accuracy =  0.8695181375203032  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  26  Best C_train =  26  gamma_train =  0.091  best_gamma_train=  0.091  Accuracy_train =  0.9388114254771897  Best Accuracy_train =  0.9388114254771897
#
# C=  26  Best C =  1  gamma =  0.091  best_gamma=  0.051000000000000004  Accuracy =  0.8689767190037899  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  26  Best C_train =  26  gamma_train =  0.096  best_gamma_train=  0.096  Accuracy_train =  0.9405712738594829  Best Accuracy_train =  0.9405712738594829
#
# C=  26  Best C =  1  gamma =  0.096  best_gamma=  0.051000000000000004  Accuracy =  0.8662696264212236  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  51  Best C_train =  26  gamma_train =  0.001  best_gamma_train=  0.096  Accuracy_train =  0.8653039122783268  Best Accuracy_train =  0.9405712738594829
#
# C=  51  Best C =  1  gamma =  0.001  best_gamma=  0.051000000000000004  Accuracy =  0.8511099079588522  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  51  Best C_train =  26  gamma_train =  0.006  best_gamma_train=  0.096  Accuracy_train =  0.8877758223906863  Best Accuracy_train =  0.9405712738594829
#
# C=  51  Best C =  1  gamma =  0.006  best_gamma=  0.051000000000000004  Accuracy =  0.8668110449377369  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  51  Best C_train =  26  gamma_train =  0.011  best_gamma_train=  0.096  Accuracy_train =  0.8967104372546365  Best Accuracy_train =  0.9405712738594829
#
# C=  51  Best C =  1  gamma =  0.011  best_gamma=  0.051000000000000004  Accuracy =  0.8662696264212236  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  51  Best C_train =  26  gamma_train =  0.016  best_gamma_train=  0.096  Accuracy_train =  0.9033437119263571  Best Accuracy_train =  0.9405712738594829
#
# C=  51  Best C =  1  gamma =  0.016  best_gamma=  0.051000000000000004  Accuracy =  0.8668110449377369  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  51  Best C_train =  26  gamma_train =  0.021  best_gamma_train=  0.096  Accuracy_train =  0.9069987816434276  Best Accuracy_train =  0.9405712738594829
#
# C=  51  Best C =  1  gamma =  0.021  best_gamma=  0.051000000000000004  Accuracy =  0.8662696264212236  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  51  Best C_train =  26  gamma_train =  0.026000000000000002  best_gamma_train=  0.096  Accuracy_train =  0.9114660890754027  Best Accuracy_train =  0.9405712738594829
#
# C=  51  Best C =  1  gamma =  0.026000000000000002  best_gamma=  0.051000000000000004  Accuracy =  0.8689767190037899  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  51  Best C_train =  26  gamma_train =  0.031  best_gamma_train=  0.096  Accuracy_train =  0.9157980235548937  Best Accuracy_train =  0.9405712738594829
#
# C=  51  Best C =  1  gamma =  0.031  best_gamma=  0.051000000000000004  Accuracy =  0.8700595560368165  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  51  Best C_train =  26  gamma_train =  0.036000000000000004  best_gamma_train=  0.096  Accuracy_train =  0.9182347366996074  Best Accuracy_train =  0.9405712738594829
#
# C=  51  Best C =  1  gamma =  0.036000000000000004  best_gamma=  0.051000000000000004  Accuracy =  0.8689767190037899  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  51  Best C_train =  26  gamma_train =  0.041  best_gamma_train=  0.096  Accuracy_train =  0.9221605523216462  Best Accuracy_train =  0.9405712738594829
#
# C=  51  Best C =  1  gamma =  0.041  best_gamma=  0.051000000000000004  Accuracy =  0.8662696264212236  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  51  Best C_train =  26  gamma_train =  0.046  best_gamma_train=  0.096  Accuracy_train =  0.9252741302287802  Best Accuracy_train =  0.9405712738594829
#
# C=  51  Best C =  1  gamma =  0.046  best_gamma=  0.051000000000000004  Accuracy =  0.8657282079047104  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  51  Best C_train =  26  gamma_train =  0.051000000000000004  best_gamma_train=  0.096  Accuracy_train =  0.9274400974685257  Best Accuracy_train =  0.9405712738594829
#
# C=  51  Best C =  1  gamma =  0.051000000000000004  best_gamma=  0.051000000000000004  Accuracy =  0.865186789388197  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  51  Best C_train =  26  gamma_train =  0.056  best_gamma_train=  0.096  Accuracy_train =  0.930689048328144  Best Accuracy_train =  0.9405712738594829
#
# C=  51  Best C =  1  gamma =  0.056  best_gamma=  0.051000000000000004  Accuracy =  0.8646453708716838  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  51  Best C_train =  26  gamma_train =  0.061  best_gamma_train=  0.096  Accuracy_train =  0.9328550155678895  Best Accuracy_train =  0.9405712738594829
#
# C=  51  Best C =  1  gamma =  0.061  best_gamma=  0.051000000000000004  Accuracy =  0.8673524634542501  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  51  Best C_train =  26  gamma_train =  0.066  best_gamma_train=  0.096  Accuracy_train =  0.9356978475700555  Best Accuracy_train =  0.9405712738594829
#
# C=  51  Best C =  1  gamma =  0.066  best_gamma=  0.051000000000000004  Accuracy =  0.8678938819707634  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  51  Best C_train =  26  gamma_train =  0.07100000000000001  best_gamma_train=  0.096  Accuracy_train =  0.937863814809801  Best Accuracy_train =  0.9405712738594829
#
# C=  51  Best C =  1  gamma =  0.07100000000000001  best_gamma=  0.051000000000000004  Accuracy =  0.8668110449377369  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  51  Best C_train =  51  gamma_train =  0.076  best_gamma_train=  0.076  Accuracy_train =  0.9407066468119669  Best Accuracy_train =  0.9407066468119669
#
# C=  51  Best C =  1  gamma =  0.076  best_gamma=  0.051000000000000004  Accuracy =  0.8646453708716838  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  51  Best C_train =  51  gamma_train =  0.081  best_gamma_train=  0.081  Accuracy_train =  0.9416542574793556  Best Accuracy_train =  0.9416542574793556
#
# C=  51  Best C =  1  gamma =  0.081  best_gamma=  0.051000000000000004  Accuracy =  0.8641039523551706  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  51  Best C_train =  51  gamma_train =  0.08600000000000001  best_gamma_train=  0.08600000000000001  Accuracy_train =  0.943549478814133  Best Accuracy_train =  0.943549478814133
#
# C=  51  Best C =  1  gamma =  0.08600000000000001  best_gamma=  0.051000000000000004  Accuracy =  0.8646453708716838  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  51  Best C_train =  51  gamma_train =  0.091  best_gamma_train=  0.091  Accuracy_train =  0.9462569378638148  Best Accuracy_train =  0.9462569378638148
#
# C=  51  Best C =  1  gamma =  0.091  best_gamma=  0.051000000000000004  Accuracy =  0.8641039523551706  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  51  Best C_train =  51  gamma_train =  0.096  best_gamma_train=  0.096  Accuracy_train =  0.947881413293624  Best Accuracy_train =  0.947881413293624
#
# C=  51  Best C =  1  gamma =  0.096  best_gamma=  0.051000000000000004  Accuracy =  0.8657282079047104  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  76  Best C_train =  51  gamma_train =  0.001  best_gamma_train=  0.096  Accuracy_train =  0.8677406254230404  Best Accuracy_train =  0.947881413293624
#
# C=  76  Best C =  1  gamma =  0.001  best_gamma=  0.051000000000000004  Accuracy =  0.8543584190579318  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  76  Best C_train =  51  gamma_train =  0.006  best_gamma_train=  0.096  Accuracy_train =  0.888723433058075  Best Accuracy_train =  0.947881413293624
#
# C=  76  Best C =  1  gamma =  0.006  best_gamma=  0.051000000000000004  Accuracy =  0.8662696264212236  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  76  Best C_train =  51  gamma_train =  0.011  best_gamma_train=  0.096  Accuracy_train =  0.8990117774468661  Best Accuracy_train =  0.947881413293624
#
# C=  76  Best C =  1  gamma =  0.011  best_gamma=  0.051000000000000004  Accuracy =  0.865186789388197  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  76  Best C_train =  51  gamma_train =  0.016  best_gamma_train=  0.096  Accuracy_train =  0.9049681873561662  Best Accuracy_train =  0.947881413293624
#
# C=  76  Best C =  1  gamma =  0.016  best_gamma=  0.051000000000000004  Accuracy =  0.865186789388197  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  76  Best C_train =  51  gamma_train =  0.021  best_gamma_train=  0.096  Accuracy_train =  0.910518478408014  Best Accuracy_train =  0.947881413293624
#
# C=  76  Best C =  1  gamma =  0.021  best_gamma=  0.051000000000000004  Accuracy =  0.8673524634542501  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  76  Best C_train =  51  gamma_train =  0.026000000000000002  best_gamma_train=  0.096  Accuracy_train =  0.9152565317449574  Best Accuracy_train =  0.947881413293624
#
# C=  76  Best C =  1  gamma =  0.026000000000000002  best_gamma=  0.051000000000000004  Accuracy =  0.8727666486193828  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  76  Best C_train =  51  gamma_train =  0.031  best_gamma_train=  0.096  Accuracy_train =  0.9183701096520915  Best Accuracy_train =  0.947881413293624
#
# C=  76  Best C =  1  gamma =  0.031  best_gamma=  0.051000000000000004  Accuracy =  0.8657282079047104  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  76  Best C_train =  51  gamma_train =  0.036000000000000004  best_gamma_train=  0.096  Accuracy_train =  0.9224312982266143  Best Accuracy_train =  0.947881413293624
#
# C=  76  Best C =  1  gamma =  0.036000000000000004  best_gamma=  0.051000000000000004  Accuracy =  0.8678938819707634  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  76  Best C_train =  51  gamma_train =  0.041  best_gamma_train=  0.096  Accuracy_train =  0.9260863679436848  Best Accuracy_train =  0.947881413293624
#
# C=  76  Best C =  1  gamma =  0.041  best_gamma=  0.051000000000000004  Accuracy =  0.8635625338386573  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  76  Best C_train =  51  gamma_train =  0.046  best_gamma_train=  0.096  Accuracy_train =  0.9279815892784622  Best Accuracy_train =  0.947881413293624
#
# C=  76  Best C =  1  gamma =  0.046  best_gamma=  0.051000000000000004  Accuracy =  0.8657282079047104  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  76  Best C_train =  51  gamma_train =  0.051000000000000004  best_gamma_train=  0.096  Accuracy_train =  0.9323135237579532  Best Accuracy_train =  0.947881413293624
#
# C=  76  Best C =  1  gamma =  0.051000000000000004  best_gamma=  0.051000000000000004  Accuracy =  0.8641039523551706  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  76  Best C_train =  51  gamma_train =  0.056  best_gamma_train=  0.096  Accuracy_train =  0.9339379991877623  Best Accuracy_train =  0.947881413293624
#
# C=  76  Best C =  1  gamma =  0.056  best_gamma=  0.051000000000000004  Accuracy =  0.8657282079047104  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  76  Best C_train =  51  gamma_train =  0.061  best_gamma_train=  0.096  Accuracy_train =  0.937728441857317  Best Accuracy_train =  0.947881413293624
#
# C=  76  Best C =  1  gamma =  0.061  best_gamma=  0.051000000000000004  Accuracy =  0.8673524634542501  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  76  Best C_train =  51  gamma_train =  0.066  best_gamma_train=  0.096  Accuracy_train =  0.9407066468119669  Best Accuracy_train =  0.947881413293624
#
# C=  76  Best C =  1  gamma =  0.066  best_gamma=  0.051000000000000004  Accuracy =  0.865186789388197  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  76  Best C_train =  51  gamma_train =  0.076  best_gamma_train=  0.096  Accuracy_train =  0.9444970894815216  Best Accuracy_train =  0.947881413293624
#
# C=  76  Best C =  1  gamma =  0.076  best_gamma=  0.051000000000000004  Accuracy =  0.8624796968056307  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  76  Best C_train =  51  gamma_train =  0.081  best_gamma_train=  0.096  Accuracy_train =  0.9467984296737512  Best Accuracy_train =  0.947881413293624
#
# C=  76  Best C =  1  gamma =  0.081  best_gamma=  0.051000000000000004  Accuracy =  0.8635625338386573  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  76  Best C_train =  76  gamma_train =  0.08600000000000001  best_gamma_train=  0.08600000000000001  Accuracy_train =  0.9484229051035603  Best Accuracy_train =  0.9484229051035603
#
# C=  76  Best C =  1  gamma =  0.08600000000000001  best_gamma=  0.051000000000000004  Accuracy =  0.8635625338386573  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  76  Best C_train =  76  gamma_train =  0.091  best_gamma_train=  0.091  Accuracy_train =  0.9507242452957899  Best Accuracy_train =  0.9507242452957899
#
# C=  76  Best C =  1  gamma =  0.091  best_gamma=  0.051000000000000004  Accuracy =  0.8613968597726043  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  76  Best C_train =  76  gamma_train =  0.096  best_gamma_train=  0.096  Accuracy_train =  0.95370245025044  Best Accuracy_train =  0.95370245025044
#
# C=  76  Best C =  1  gamma =  0.096  best_gamma=  0.051000000000000004  Accuracy =  0.8608554412560909  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  101  Best C_train =  76  gamma_train =  0.001  best_gamma_train=  0.096  Accuracy_train =  0.8690943549478815  Best Accuracy_train =  0.95370245025044
#
# C=  101  Best C =  1  gamma =  0.001  best_gamma=  0.051000000000000004  Accuracy =  0.8554412560909583  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  101  Best C_train =  76  gamma_train =  0.006  best_gamma_train=  0.096  Accuracy_train =  0.8917016380127251  Best Accuracy_train =  0.95370245025044
#
# C=  101  Best C =  1  gamma =  0.006  best_gamma=  0.051000000000000004  Accuracy =  0.8662696264212236  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  101  Best C_train =  76  gamma_train =  0.011  best_gamma_train=  0.096  Accuracy_train =  0.901583863544064  Best Accuracy_train =  0.95370245025044
#
# C=  101  Best C =  1  gamma =  0.011  best_gamma=  0.051000000000000004  Accuracy =  0.865186789388197  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  101  Best C_train =  76  gamma_train =  0.016  best_gamma_train=  0.096  Accuracy_train =  0.9069987816434276  Best Accuracy_train =  0.95370245025044
#
# C=  101  Best C =  1  gamma =  0.016  best_gamma=  0.051000000000000004  Accuracy =  0.8646453708716838  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  101  Best C_train =  76  gamma_train =  0.021  best_gamma_train=  0.096  Accuracy_train =  0.9121429538378232  Best Accuracy_train =  0.95370245025044
#
# C=  101  Best C =  1  gamma =  0.021  best_gamma=  0.051000000000000004  Accuracy =  0.8684353004872767  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  101  Best C_train =  76  gamma_train =  0.026000000000000002  best_gamma_train=  0.096  Accuracy_train =  0.9166102612697983  Best Accuracy_train =  0.95370245025044
#
# C=  101  Best C =  1  gamma =  0.026000000000000002  best_gamma=  0.051000000000000004  Accuracy =  0.8689767190037899  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  101  Best C_train =  76  gamma_train =  0.031  best_gamma_train=  0.096  Accuracy_train =  0.921889806416678  Best Accuracy_train =  0.95370245025044
#
# C=  101  Best C =  1  gamma =  0.031  best_gamma=  0.051000000000000004  Accuracy =  0.8646453708716838  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  101  Best C_train =  76  gamma_train =  0.036000000000000004  best_gamma_train=  0.096  Accuracy_train =  0.9256802490862326  Best Accuracy_train =  0.95370245025044
#
# C=  101  Best C =  1  gamma =  0.036000000000000004  best_gamma=  0.051000000000000004  Accuracy =  0.8646453708716838  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  101  Best C_train =  76  gamma_train =  0.041  best_gamma_train=  0.096  Accuracy_train =  0.9285230810883985  Best Accuracy_train =  0.95370245025044
#
# C=  101  Best C =  1  gamma =  0.041  best_gamma=  0.051000000000000004  Accuracy =  0.865186789388197  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  101  Best C_train =  76  gamma_train =  0.046  best_gamma_train=  0.096  Accuracy_train =  0.9323135237579532  Best Accuracy_train =  0.95370245025044
#
# C=  101  Best C =  1  gamma =  0.046  best_gamma=  0.051000000000000004  Accuracy =  0.8646453708716838  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  101  Best C_train =  76  gamma_train =  0.051000000000000004  best_gamma_train=  0.096  Accuracy_train =  0.9339379991877623  Best Accuracy_train =  0.95370245025044
#
# C=  101  Best C =  1  gamma =  0.051000000000000004  best_gamma=  0.051000000000000004  Accuracy =  0.865186789388197  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  101  Best C_train =  76  gamma_train =  0.056  best_gamma_train=  0.096  Accuracy_train =  0.9375930689048328  Best Accuracy_train =  0.95370245025044
#
# C=  101  Best C =  1  gamma =  0.056  best_gamma=  0.051000000000000004  Accuracy =  0.8662696264212236  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  101  Best C_train =  76  gamma_train =  0.061  best_gamma_train=  0.096  Accuracy_train =  0.9411127656694193  Best Accuracy_train =  0.95370245025044
#
# C=  101  Best C =  1  gamma =  0.061  best_gamma=  0.051000000000000004  Accuracy =  0.8641039523551706  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  101  Best C_train =  76  gamma_train =  0.066  best_gamma_train=  0.096  Accuracy_train =  0.942195749289292  Best Accuracy_train =  0.95370245025044
#
# C=  101  Best C =  1  gamma =  0.066  best_gamma=  0.051000000000000004  Accuracy =  0.865186789388197  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  101  Best C_train =  76  gamma_train =  0.07100000000000001  best_gamma_train=  0.096  Accuracy_train =  0.945173954243942  Best Accuracy_train =  0.95370245025044
#
# C=  101  Best C =  1  gamma =  0.07100000000000001  best_gamma=  0.051000000000000004  Accuracy =  0.8603140227395777  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  101  Best C_train =  76  gamma_train =  0.076  best_gamma_train=  0.096  Accuracy_train =  0.9476106673886557  Best Accuracy_train =  0.95370245025044
#
# C=  101  Best C =  1  gamma =  0.076  best_gamma=  0.051000000000000004  Accuracy =  0.8635625338386573  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  101  Best C_train =  76  gamma_train =  0.081  best_gamma_train=  0.096  Accuracy_train =  0.949370515770949  Best Accuracy_train =  0.95370245025044
#
# C=  101  Best C =  1  gamma =  0.081  best_gamma=  0.051000000000000004  Accuracy =  0.8608554412560909  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  101  Best C_train =  76  gamma_train =  0.08600000000000001  best_gamma_train=  0.096  Accuracy_train =  0.9520779748206308  Best Accuracy_train =  0.95370245025044
#
# C=  101  Best C =  1  gamma =  0.08600000000000001  best_gamma=  0.051000000000000004  Accuracy =  0.8597726042230645  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  101  Best C_train =  101  gamma_train =  0.091  best_gamma_train=  0.091  Accuracy_train =  0.9550561797752809  Best Accuracy_train =  0.9550561797752809
#
# C=  101  Best C =  1  gamma =  0.091  best_gamma=  0.051000000000000004  Accuracy =  0.8608554412560909  Best Accuracy =  0.8749323226854359
#
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C_train=  101  Best C_train =  101  gamma_train =  0.096  best_gamma_train=  0.096  Accuracy_train =  0.9570867740625423  Best Accuracy_train =  0.9570867740625423
#
# C=  101  Best C =  1  gamma =  0.096  best_gamma=  0.051000000000000004  Accuracy =  0.8603140227395777  Best Accuracy =  0.8749323226854359

# %%
import pandas as pd
clf = SVC(C=51,gamma=0.006,decision_function_shape='ovo')
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
from sklearn import metrics
print("Accuracy :",metrics.accuracy_score(y_pred, y_test)*100)
from sklearn.metrics import cohen_kappa_score
print("Cohen Kappa Score :",cohen_kappa_score(y_pred, y_test)*100)
from sklearn.metrics import confusion_matrix,classification_report
mat = confusion_matrix(y_pred, y_test)
pd.DataFrame(mat)
# print(confusion_matrix(y_test, y_pred ))
print(classification_report(y_test, y_pred ))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Accuracy : 86.68110449377369
# Cohen Kappa Score : 84.36163171660246
#               precision    recall  f1-score   support
#
#          2.0       0.82      0.84      0.83       294
#          3.0       0.83      0.75      0.79       171
#          5.0       0.90      0.97      0.93        99
#          6.0       0.96      0.99      0.97       151
#          8.0       0.99      1.00      0.99        88
#         10.0       0.76      0.80      0.78       191
#         11.0       0.82      0.82      0.82       482
#         12.0       0.87      0.82      0.84       104
#         14.0       1.00      0.98      0.99       267
#
#     accuracy                           0.87      1847
#    macro avg       0.88      0.88      0.88      1847
# weighted avg       0.87      0.87      0.87      1847
